# %% [markdown]
# #### Import necessary library

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# From here I can see customer id is not required. So ill drop this column
df = pd.read_csv("customer_churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4782  6175-IRFIT    Male              0      No         No       5
# 4386  3400-ESFUW    Male              0     Yes        Yes      55
# 410   0334-GDDSO    Male              1      No         No       3
# 5731  4936-YPJNK  Female              0      No         No      10
# 1461  6234-PFPXL    Male              0     Yes         No      22
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4782          Yes            No     Fiber optic                   No  ...
# 4386          Yes            No             DSL                  Yes  ...
# 410           Yes           Yes     Fiber optic                   No  ...
# 5731          Yes            No              No  No internet service  ...
# 1461          Yes           Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 4782                   No                   No                   No
# 4386                   No                  Yes                   No
# 410                    No                   No                   No
# 5731  No internet service  No internet service  No internet service
# 1461                   No                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 4782                  Yes  Month-to-month               No
# 4386                   No        Two year               No
# 410                    No  Month-to-month              Yes
# 5731  No internet service  Month-to-month              Yes
# 1461                   No  Month-to-month               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 4782               Mailed check          78.75        426.35    No
# 4386  Bank transfer (automatic)          57.55        3046.4   Yes
# 410            Electronic check          81.35         233.7   Yes
# 5731               Mailed check          19.90        199.45    No
# 1461    Credit card (automatic)          95.90       2234.95    No
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# # Data Exploration
# From here we will modify our data for machine learning modelf

# %%
df.drop('customerID', axis='columns', inplace = True)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0                 Yes           Electronic check           29.85        29.85
# 1                  No               Mailed check           56.95       1889.5
# 2                 Yes               Mailed check           53.85       108.15
# 3                  No  Bank transfer (automatic)           42.30      1840.75
# 4                 Yes           Electronic check           70.70       151.65
# ...               ...                        ...             ...          ...
# 7038              Yes               Mailed check           84.80       1990.5
# 7039              Yes    Credit card (automatic)          103.20       7362.9
# 7040              Yes           Electronic check           29.60       346.45
# 7041              Yes               Mailed check           74.40        306.6
# 7042              Yes  Bank transfer (automatic)          105.65       6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 20 columns]

# %%
#string value, so have to make it numeric
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File E:\Code\Py Code\Python installation\lib\site-packages\pandas\_libs\lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [214], in <cell line: 1>()
# ----> 1 pd.to_numeric(df.TotalCharges)
#
# File E:\Code\Py Code\Python installation\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# File E:\Code\Py Code\Python installation\lib\site-packages\pandas\_libs\lib.pyx:2411, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 488

# %%
pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
# Here if a space found, it will be ignored.
df[pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.iloc[488]
# Out:
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %%
df.iloc[488].TotalCharges
# Out:
# ' '

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df1.TotalCharges)
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\AJ\AppData\Local\Temp\ipykernel_6136\973151263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Histogram between tenure and churn

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number of Customers")
plt.title("Customer Churn Prediction Visualization")

plt.hist([tenure_churn_yes, tenure_churn_no], color = ['green', 'red'], label=['Churn =Yes', 'Churn=No'])
plt.legend()

# %% [markdown]
# ### Monthly Charges Histogram

# %%
mc_churn_no = df1[df1.Churn == 'No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn == 'Yes'].MonthlyCharges

plt.xlabel("Monthly Charges")
plt.ylabel("Number of customers")
plt.xlabel("Customer Churn prediction visualization")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69,89, 79, 120, 112, 100]

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green', 'red'], label = ['Churn=Yes', 'Churn=No'])
plt.legend()

# %% [markdown]
# ##### Find unique object values so that I can make it into 0 to 1 value

# %%
def print_unique_col_values(df):
    for column in df:
        if df[column].dtypes=='object':
            print(f'{column} : {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
#Here I will not use one hot encoding because it's only two value. If it is more then 2 value I would have used it.
df1.replace('No internet service', 'No', inplace = True)
df1.replace('No phone service', 'No', inplace = True)
# Out:
# C:\Users\AJ\AppData\Local\Temp\ipykernel_6136\1330973912.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace = True)
# C:\Users\AJ\AppData\Local\Temp\ipykernel_6136\1330973912.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace = True)

# %%
print_unique_col_values(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
#Replace yes and no to 1,0.
yes_no_columns = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                 'StreamingTV', 'StreamingMovies', 'PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# C:\Users\AJ\AppData\Local\Temp\ipykernel_6136\3081892482.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
#now print unique values.
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# Churn: [0 1]

# %%
#see the values after manupulation!
df1.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3877  Female              0        1           1      21             0
# 4050    Male              1        1           0      58             1
# 758   Female              0        0           1      15             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 3877              0             DSL               1             0
# 4050              1     Fiber optic               0             1
# 758               0     Fiber optic               0             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 3877                 1            0            1                1
# 4050                 0            0            1                1
# 758                  0            0            0                1
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 3877        One year                 1           Electronic check
# 4050  Month-to-month                 1           Electronic check
# 758   Month-to-month                 1  Bank transfer (automatic)
#
#       MonthlyCharges TotalCharges  Churn
# 3877           55.95      1157.05      1
# 4050           98.90       5780.7      0
# 758            85.90      1269.55      1

# %%
df1['gender'].replace({'Female':1, 'Male':0},inplace=True)
# Out:
# C:\Users\AJ\AppData\Local\Temp\ipykernel_6136\940752256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1, 'Male':0},inplace=True)

# %%
df1['gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ## One Hottttttttt Encoding!! ^_^

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService', 'Contract', 'PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5682       1              0        1           0       1             0
# 6462       0              0        0           0       2             1
# 6186       0              0        1           0      47             1
# 465        0              0        0           0      70             0
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5682              0               0             0                 0  ...
# 6462              0               0             1                 0  ...
# 6186              1               1             0                 1  ...
# 465               0               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5682                    1                            0                   0
# 6462                    0                            1                   0
# 6186                    0                            1                   0
# 465                     1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5682                        1                  0                  0
# 6462                        1                  0                  0
# 6186                        0                  1                  0
# 465                         0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5682                                        0
# 6462                                        0
# 6186                                        0
# 465                                         0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5682                                      0                               1
# 6462                                      0                               1
# 6186                                      1                               0
# 465                                       0                               0
#
#       PaymentMethod_Mailed check
# 5682                           0
# 6462                           0
# 6186                           0
# 465                            1
#
# [4 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %% [markdown]
# # Data Scaling

# %%
cols_to_scale = ['tenure', 'MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 4586       1              0        1           1  1.000000             1
# 2098       0              0        0           0  0.014085             1
# 6553       1              0        1           1  0.845070             0
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4586              1               1             1                 1  ...
# 2098              1               1             0                 0  ...
# 6553              0               0             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 4586                    0                            1                   0
# 2098                    0                            1                   0
# 6553                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 4586                        0                  0                  1
# 2098                        1                  0                  0
# 6553                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 4586                                        1
# 2098                                        0
# 6553                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4586                                      0                               0
# 2098                                      0                               0
# 6553                                      0                               0
#
#       PaymentMethod_Mailed check
# 4586                           0
# 2098                           1
# 6553                           0
#
# [3 rows x 27 columns]

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %% [markdown]
# # Train_Test_Split

# %%
x = df2.drop('Churn', axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state = 5)

# %%
x_train.shape
# Out:
# (5625, 26)

# %%
x_test.shape
# Out:
# (1407, 26)

# %%
x_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(x_train.columns)
# Out:
# 26

# %% [markdown]
# # Neural Network

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
    
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(x_train,y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.4839 - accuracy: 0.7657
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.7929
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4203 - accuracy: 0.7996
# Epoch 4/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.8021
# Epoch 5/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4143 - accuracy: 0.8020
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.8037
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.8041
# Epoch 8/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4098 - accuracy: 0.8039
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8066
# Epoch 10/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4086 - accuracy: 0.8084
# Epoch 11/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4081 - accuracy: 0.8059
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8073
# Epoch 13/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4060 - accuracy: 0.8089
# Epoch 14/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4056 - accuracy: 0.8100
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8087
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8089
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8114
# Epoch 18/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4032 - accuracy: 0.8091
# Epoch 19/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8084
# Epoch 20/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4022 - accuracy: 0.8107
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4016 - accuracy: 0.8114
# Epoch 22/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8116
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8114
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8119
# Epoch 25/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4003 - accuracy: 0.8149
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8117
# Epoch 27/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3992 - accuracy: 0.8119
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3998 - accuracy: 0.8146
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8133
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8123
# Epoch 31/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3982 - accuracy: 0.8121
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8130
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8140
# Epoch 34/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3987 - accuracy: 0.8117
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8142
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8103
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8133
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8140
# Epoch 39/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3966 - accuracy: 0.8151
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 0.8124
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8132
# Epoch 42/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3959 - accuracy: 0.8146
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8137
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8130
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8165
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8139
# Epoch 47/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8137
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8155
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3937 - accuracy: 0.8148
# Epoch 50/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8130
# Epoch 51/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8148
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8148
# Epoch 53/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8151
# Epoch 54/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8156
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8155
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8146
# Epoch 57/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3919 - accuracy: 0.8174
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3910 - accuracy: 0.8190
# Epoch 59/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3919 - accuracy: 0.8164
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3903 - accuracy: 0.8151
# Epoch 61/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3903 - accuracy: 0.8156
# Epoch 62/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3903 - accuracy: 0.8164
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3900 - accuracy: 0.8185
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8188
# Epoch 65/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3894 - accuracy: 0.8196
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3896 - accuracy: 0.8185
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8192
# Epoch 68/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3885 - accuracy: 0.8171
# Epoch 69/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3892 - accuracy: 0.8176
# Epoch 70/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3888 - accuracy: 0.8171
# Epoch 71/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3877 - accuracy: 0.8199
# Epoch 72/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3877 - accuracy: 0.8169
# Epoch 73/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3877 - accuracy: 0.8176
# Epoch 74/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3876 - accuracy: 0.8199
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3875 - accuracy: 0.8192
# Epoch 76/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3869 - accuracy: 0.8197
# Epoch 77/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3867 - accuracy: 0.8206
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8204
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8196
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8206
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8215
# Epoch 82/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8185
# Epoch 83/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3854 - accuracy: 0.8219
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 0.8228
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8213
# Epoch 86/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3851 - accuracy: 0.8228
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3843 - accuracy: 0.8219
# Epoch 88/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3846 - accuracy: 0.8204
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 0.8224
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8238
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3837 - accuracy: 0.8206
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8217
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8220
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8215
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.8226
# Epoch 96/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3825 - accuracy: 0.8233
# Epoch 97/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.8228
# Epoch 98/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3824 - accuracy: 0.8235
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8236
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8229

# %%
model.evaluate(x_test, y_test)
# Out:
# 44/44 [==============================] - 1s 3ms/step - loss: 0.4437 - accuracy: 0.7925
# [0.4437088072299957, 0.7924662232398987]

# %%
yp = model.predict(x_test)
yp[:5]
# Out:
# array([[0.24522471],
#        [0.41840887],
#        [0.01988521],
#        [0.67443675],
#        [0.4900317 ]], dtype=float32)

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 0, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86       999
#            1       0.67      0.57      0.61       408
#
#     accuracy                           0.79      1407
#    macro avg       0.75      0.73      0.74      1407
# weighted avg       0.79      0.79      0.79      1407

# %% [markdown]
# ### Confusion matrix

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test, predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
